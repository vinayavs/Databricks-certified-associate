# %%
print("Hello World..!!")
# Out:
# Hello World..!!

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2243488185639557#setting/sparkui/0707-025013-uxfqd7kg/driver-7500249505423705910">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# %sh
ls -ltr /
# Out:
# ls: /Volumes: Operation not permitted
# total 88
# -r-xr-xr-x   1 root   root     271 Jan  1  1970 BUILD
# drwxr-xr-x   2 root   root    4096 Apr 15  2020 boot
# lrwxrwxrwx   1 root   root       8 Oct 19  2022 sbin -> usr/sbin
# lrwxrwxrwx   1 root   root      10 Oct 19  2022 libx32 -> usr/libx32
# lrwxrwxrwx   1 root   root       9 Oct 19  2022 lib64 -> usr/lib64
# lrwxrwxrwx   1 root   root       9 Oct 19  2022 lib32 -> usr/lib32
# lrwxrwxrwx   1 root   root       7 Oct 19  2022 lib -> usr/lib
# lrwxrwxrwx   1 root   root       7 Oct 19  2022 bin -> usr/bin
# drwxr-xr-x   2 root   root    4096 Oct 19  2022 srv
# drwxr-xr-x   2 root   root    4096 Oct 19  2022 media
# drwxr-xr-x   4 root   root    4096 Nov 30  2022 opt
# drwxr-xr-x   1 root   root    4096 Nov 30  2022 home
# drwxr-xr-x  14 root   root    4096 Jul 15 13:57 usr
# drwxr-xr-x   1 root   root    4096 Jul 15 13:57 var
# dr-xr-xr-x  13 root   root       0 Jul 15 16:49 sys
# ...

# %%
# %fs ls /
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
dbutils.help()
# Out:
# <div class = "ansiout">
# This module provides various utilities for users to interact with the rest of Databricks.
# ...

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
# ...

# %%
for file_details in dbutils.fs.ls('/FileStore'):
    print(file_details)
# Out:
# FileInfo(path='dbfs:/FileStore/tables/', name='tables/', size=0, modificationTime=0)

# %%
for file_details in dbutils.fs.ls('/FileStore'):
    print(file_details.path)
    print(file_details.name)
    print(file_details.size)
    print(file_details.modificationTime)
# Out:
# dbfs:/FileStore/tables/
# tables/
# 0
# 0
